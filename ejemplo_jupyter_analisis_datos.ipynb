# %% [markdown]
# <a href="https://colab.research.google.com/github/apchavezr/Programacion_Analisis_Datos/blob/main/ejemplo_jupyter_analisis_datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Análisis de Datos en Python
#
# Este es un ejemplo con **Jupyter Notebook** o **Google Colab**.
# A continuación, se carga un archivo CSV con `pandas` y se muestran las primeras filas del dataset.
#
# 📌 Recuerde:
# - Las **celdas Markdown** permiten incluir texto, listas, enlaces y ecuaciones matemáticas con $\LaTeX$.
# - Las **celdas de código** ejecutan instrucciones en Python u otros lenguajes configurados.
#
# ---

# %%
# Importar la librería pandas
import pandas as pd

# Leer el archivo CSV (puede usar uno local o de internet)
url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv"
datos = pd.read_csv(url)

# Mostrar las primeras 5 filas
datos.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ### Resultado del análisis
#
# Se ha cargado el conjunto de datos de flores Iris.
# Con `datos.head()` se muestran las primeras filas, lo cual es útil para explorar la estructura general del DataFrame.
#
# ✅ Esta operación es útil como paso inicial en cualquier flujo de trabajo de análisis exploratorio.
